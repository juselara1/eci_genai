# %% [markdown]
# # Evaluacion
# ---
#
# - 60% Talleres (individual).
# - 40% Proyecto (grupal max 3).

# %% [markdown]
# # Tematica
# ---
#
# 1. Introduccion a modelos del lenguaje.
# 2. Modelos probabilisticos del lenguaje.
# 3. Redes neuronales.
# 4. Transformers.
# 5. Fine-tuning.
# 6. LangChain.
# 7. LangGraph.
# 8. Embeddings / RAG / PageIndex / GraphRag.
# 9. Tools / MCPs (FastMCP).
# 10. Prompt optimization.
