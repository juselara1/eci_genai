# %% [markdown]
# # Proyecto Final
# ---
#
# En este notebook encontrara una plantilla que puede utilizar para el proyecto final. Recuerde llenar los campos correspondientes y editar el notebook de acuerdo a las necesidades de su proyecto. Tenga en cuenta las siguientes consideraciones:
#
# - El proyecto lo puede realizar maximo en grupos de 3 personas.
# - La fecha maxima de entrega es el domingo 30 de noviembre de 2025 a las 23:59.
# - Debe enviar el proyecto por medio de [este enlace](https://forms.gle/hKUSCjyrfogtW93J9).
# - El tema del proyecto es de eleccion libre siempre y cuando aplique alguna herramienta vista en clase o muy relacionada a la tematica de la misma.
# - Para el entregable debe adjuntar el codigo fuente y un video de 10 minutos donde explique el proyecto y presente una demostracion de la solucion en funcionamiento.

# %% [markdown]
# ## Rubrica de Evaluacion
# ---
#
# Revise la siguiente rubrica con los elementos que se evaluaran del proyecto:
#
# <table>
# <thead>
#     <tr>
#         <th>Criterio</th> <th>Descripcion</th> <th>Porcentaje</th>
#     </tr>
# </thead>
# <tbody>
#     <tr>
#         <td>Aplicacion</td>
#         <td>
#             <ul>
#                 <li>La problematica a solucionar es clara.</li>
#                 <li>El proyecto soluciona la problematica propuesta.</li>
#                 <li>La aplicacion esta relacionada con GenAI.</li>
#             </ul>
#         </td>
#         <td>30%</td>
#     </tr>
#     <tr>
#         <td>Codigo</td>
#         <td>
#             <ul>
#                 <li>El codigo implementado es limpio y entedible.</li>
#                 <li>El codigo ejecuta y no presenta errores de ejecucion.</li>
#                 <li>El codigo incorpora librerias o llamado de APIs de GenAI.</li>
#             </ul>
#         </td>
#         <td>40%</td>
#     </tr>
#     <tr>
#         <td>Video</td>
#         <td>
#             <ul>
#                 <li>El video tiene una duracion de entre 5 y 10 minutos.</li>
#                 <li>La explicacion del proyecto es clara.</li>
#                 <li>Se presenta de forma completa el proyecto junto con la problematica.</li>
#             </ul>
#         </td>
#         <td>30%</td>
#     </tr>
# </tbody>
# </table>

# %% [markdown]
# ## Estructura
# ---
#
# Puede seguir la suguiente estructura de proyecto:

# %% [markdown]
# ### Problematica
# ---
#
# Agregue una descripcion de la problematica y el contexto del proyecto, el tipo de problema que desea solucionar con GenAI. Puede agregar un objetivo general y tres objetivos especificos.

# %% [markdown]
# ### Trabajos Relacionados
# ---
#
# Puede agregar un parrafo con referencias a articulos, blogs, repositorios donde se muestre como otras personas han solucionado problemas similares.

# %% [markdown]
# ### Metodologia
# ---
#
# Agregue el codigo fuente de la solucion al problema que desea solucionar.

# %% [markdown]
# ### Resultados y Discusion
# ---
#
# Agregue los resultados obtenidos y presente una discusion sobre los mismos. Puede corroborar que tan bien funciona el codigo, en que puntos falla y que posibilidades existen con la solucion implementada.

# %% [markdown]
# ### Conclusion
# ---
#
# Agregue un parrafo con la conclusion del proyecto.
